# %% [markdown]
# # 📘 Probability — Revision Task Set

# %% [markdown]
# ## 🔹 I. Introduction to Probability & Probability Axioms

# %%
#✅ Task 1: Identify the Probability Components
#A die is rolled once.
#Identify:
#Random experiment
#Trial
#Sample space
#Event: “Getting an even number”
#rite the probability of the event.
#👉 Challenge:
 #Explain why the probability value satisfies all probability axioms.

# %% [raw]
# 1️⃣ Random Experiment:
# Rolling a die once is the random experiment.
#
# 2️⃣ Trial
# One roll of the die is a single trial.
#
# 3️⃣ Sample Space
# S={1,2,3,4,5,6}
#
# 4️⃣ Event: Getting an Even Number
# Even numbers on a die are:
# E={2,4,6}
#
# 5️⃣ Probability of the Event
#
# Formula:
#
# P(E)=Total outcomes\Number of favorable outcomes
# 	​
#
#
# Favorable outcomes = 3 → (2,4,6)
# Total outcomes = 6
#
# P(E)=6\3=0.5
#
# #Challenge: Why This Satisfies Probability Axioms

# %% [raw]
# ✅ Task 2: Verify Probability Axioms
# Given probabilities of three events:
# P(A) = 0.3
# P(B) = 0.5
# P(C) = 0.2
# Check whether these values satisfy probability axioms.
# What is P(Sample Space)?
#
#
#
# Axiom 1 — Non-Negativity
#
# Probability must satisfy:
# P(E)≥0
#
# Check values:
# P(A)=0.3≥0
# P(B)=0.5≥0
# P(C)=0.2≥0
#
# ✅ Satisfied
#
# Axiom 2 — Total Probability of Sample Space
#
# The probability of the entire sample space (S) must equal 1.
#
# P(S)=1
#
# Check the sum:
#
# P(A)+P(B)+P(C)
# 0.3+0.5+0.2=1.0
#
# P(S)=1
#
# ✅ Satisfied
#
# Axiom 3 — Additivity
#
# If events are mutually exclusive, their probabilities add.
#
# P(A∪B∪C)=P(A)+P(B)+P(C)=0.3+0.5+0.2=1
#
# P(A∪B∪C)=P(S)
#
# ✅ Satisfied

# %% [markdown]
# ## 🔹 II. Independent Events, Conditional & Bayes Probability

# %% [raw]
# ✅ Task 3: Independent or Dependent?
# Classify the following event pairs as Independent or Dependent (with reason):
# Tossing a coin twice
# Drawing two cards with replacement
# Drawing two cards without replacement
# Selecting a student and their exam result
# 👉 Challenge: Explain how independence affects probability calculation.
#
#
# 1).Tossing a Coin Twice
# Type: Independent
# Example:
# First toss → Head or Tail
# Second toss → Head or Tail
# Even if the first toss is Head, the probability of the second toss being Head is still:
# P(H)=0.5
#
#
# 2).Drawing Two Cards With Replacement
#
# Type: Independent
# Reason:
# After drawing the first card, it is put back into the deck.
# The deck returns to its original 52 cards.
# So the probability of the second draw does not change.
#
# Example:
# P(Ace on first)=4/52
# P(Ace on second)=4/52
#
# 3).Drawing Two Cards Without Replacement
#
# Type: Dependent
# Reason:
# After the first card is drawn, it is not returned to the deck.
# So the number of cards becomes 51, which changes the probability.
# Example:
# If first card is an Ace:
#
# P(Ace on second)=3/51
# The probability changed from 4/52 to 3/51.
# Therefore → Dependent events.
#
# 4). Selecting a Student and Their Exam Result
# Type: Dependent
# Reason:
# The exam result depends on the selected student.
#
# Example:
# If you pick a top student, probability of passing is high.
# If you pick a weak student, probability of passing is lower.
# So the outcome of one affects the other.
# Therefore → Dependent events.
#
# Challenge: How Independence Affects Probability Calculation
#
# For independent events:
# P(A∩B)=P(A)×P(B)
#
# Example:
# Two coin tosses getting Head both times
# P(HH)=0.5×0.5=0.25

# %% [raw]
# ✅ Task 4: Conditional & Bayes Thinking
# In a company:
# 60% employees are Engineers
# 40% are Analysts
# 70% of Engineers know Python
# 30% of Analysts know Python
# Answer:
# What is the probability that a randomly selected employee knows Python?
# If an employee knows Python, are they more likely to be an Engineer or Analyst?
# 👉 Hint:
#  This is an intuitive Bayes reasoning problem — no formula first.
#
#
# Engineers = 60% →
# P(E)=0.6
#
# Analysts = 40% →
# P(A)=0.4
#
# Python knowledge:
#
# Engineers who know Python = 70% →
# P(Python∣E)=0.7
#
# Analysts who know Python = 30% →
# P(Python∣A)=0.3
#
# 1).Probability that a Random Employee Knows Python
#
# So total probability:
# P(Python)=P(E)×P(Python∣E)+P(A)×P(Python∣A)
#
# Calculate:
#
# Engineer contribution:
#   0.6×0.7=0.42
#
# Analyst contribution:
# 0.4×0.3=0.12
#
# Total:
# P(Python)=0.42+0.12=0.54
#
#
# 2).If Someone Knows Python, Are They More Likely Engineer or Analyst?
#
# Engineers contribute 0.42
# Analysts contribute 0.12
#  Python users:
#
# P(E∣Python)=0.42/0.54=0.78
# Python users:
# P(A∣Python)=0.12/0.54=0.22

# %% [markdown]
# # 🔹 III. Marginal, Joint Probability & Contingency Tables

# %% [raw]
# ✅ Task 5: Contingency Table Interpretation
#
#
# Find:
# Joint Probability: P(Female ∩ Pass)
# Marginal Probability: P(Pass)
# Conditional Probability: P(Pass | Female)
# 👉 Challenge:
#  Explain the difference between joint and conditional probability using this table.
#
# 1).Joint Probability
#
# Number of Females who passed = 50
# P(Female∩Pass)=50/100
# P(Female∩Pass)=0.5
#
# Answer: 0.5 (50%)
#
# 2).Marginal Probability
# Total students who passed = 80
# P(Pass)=80/100
# P(Pass)=0.8
# Answer: 0.8 (80%)
#
# 3).Conditional Probability
# Females who passed = 50
# P(Pass∣Female)=50/60
# P(Pass∣Female)=0.833
# Answer: ≈ 0.83 (83.3%)

# %% [raw]
# ✅ Task 6: Reason Without Calculation
# Using the table above, answer True or False with reason:
# Passing and gender are independent events.
# Probability of passing is higher for females.
# Marginal probability ignores conditions.
# 👉 Think:
#  How would independence reflect in the contingency table values?
#
#
# 1).Passing and Gender are Independent Events
#
# Answer:False
#
# Male pass rate
# 30/40=0.75
#
# Female pass rate
# 50/60≈0.83
#
# 2).Probability of Passing is Higher for Females
#
# Answer:True
# Reason:
# Male pass probability = 75%
# Female pass probability ≈ 83%
# Since 83% > 75%, females have a higher probability of passing.
#
# 3).Marginal Probability Ignores Conditions
#
# Answer:True
#
# Reason:
# Marginal probability considers only one variable and ignores other conditions.
#
# Example from the table:
# P(Pass)=80/100=0.8
# This does not consider gender.
